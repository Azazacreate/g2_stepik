# %%
import numpy as np
import pandas as pd

# %%
# как создать DataFrame ?
np.random.seed(101)
data_1 = np.random.randint(0, 101, (4, 3))
data_1
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
index_1 = ['CA', 'NY', 'AZ', 'TX']
columns_1 = ['Jan', 'Feb', 'Mar']
df = pd.DataFrame(data_1)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data_1, index_1)
df
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df = pd.DataFrame(data_1, index_1, columns_1)
df        # DataFrame:Классический
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()    # знать:важно сколько-места занимает DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %% [markdown]
# # как читать данные из-файла ? (csv,excel,sql)

# %%
pwd
# Out:
# '/Users/a1111/Documents/_c2/f5_professional/g6_self_education/g2_stepik/h12_machine_learning_python'

# %%
ls
# Out:
# 1.2.2_ML/
# 1.2.3_slides/
# 1.2_course_materials_zip/
# 1.5.2.ipynb
# 1.5_setup_environment/
# 2.4_python_part_3.ipynb
# 4.2_array_NumPy.ipynb
# 4.3 Индексация и выбор данных.ipynb
# 4.4_operations.ipynb
# 4.5_exercises.ipynb*
# 5.2_series.ipynb
# 5.3_series_2.ipynb
# 5.4_DataFrame_1.ipynb

# %%
df = pd.read_csv('1.2.2_ML/03-Pandas/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # 5.5_DataFrame_2

# %%
print(
    df.index      # названия_строк
    ,df.columns    # названия_колонок
    ,sep='\n\n'
)
# Out:
# RangeIndex(start=0, stop=244, step=1)
#
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.head()     # показать n-строкПервые
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.tail()     # показать n-строкПоследние
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()    # информацияОбщая_DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()    # получить метрикиОсновные
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()    # поменять местами строки и колонки
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# # 5.6_DataFrame_3

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill'][:10]
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# 5    25.29
# 6     8.77
# 7    26.88
# 8    15.04
# 9    14.78
# Name: total_bill, dtype: float64

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
# как добавить колонкуНовую в-DataFrame ?
df['columnNew'] = df['tip'] + df['total_bill']

# %%
100 * df['tip'] / df['total_bill']    # получить проценты
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
df['price_per_person'] = np.round(df['price_per_person'], 2)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  columnNew
# ...

# %%
df.drop('tip', axis=1)
# Out:
#      total_bill     sex smoker   day    time  size  price_per_person  \
# 0         16.99  Female     No   Sun  Dinner     2              8.49
# 1         10.34    Male     No   Sun  Dinner     3              3.45
# 2         21.01    Male     No   Sun  Dinner     3              7.00
# 3         23.68    Male     No   Sun  Dinner     2             11.84
# 4         24.59  Female     No   Sun  Dinner     4              6.15
# ..          ...     ...    ...   ...     ...   ...               ...
# 239       29.03    Male     No   Sat  Dinner     3              9.68
# 240       27.18  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82    Male     No   Sat  Dinner     2              8.91
# 243       18.78  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  columnNew
# 0    Christy Cunningham  3560325168603410    Sun2959      18.00
# ...

# %%
df.shape
# Out:
# (244, 12)

# %% [markdown]
# ## 5.7 Датафреймы - Часть 4 - Работа со строками

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index('Payment ID')

# %%
rowOne = df.iloc[0]
rowOne
df = pd.concat([df, pd.DataFrame([rowOne])], axis=0)
df
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner   2.0
# Sun4608       10.34  1.66    Male     No   Sun  Dinner   3.0
# Sun4458       21.01  3.50    Male     No   Sun  Dinner   3.0
# Sun5260       23.68  3.31    Male     No   Sun  Dinner   2.0
# Sun2251       24.59  3.61  Female     No   Sun  Dinner   4.0
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# Sat17         17.82  1.75    Male     No   Sat  Dinner   2.0
# Thur672       18.78  3.00  Female     No  Thur  Dinner   2.0
# Sun2959       16.99  1.01  Female     No   Sun  Dinner   2.0
#
#          price_per_person          Payer Name     CC Number  columnNew    0
# Sun2959              8.49  Christy Cunningham  3.560325e+15      18.00  NaN
# Sun4608              3.45      Douglas Tucker  4.478071e+15      12.00  NaN
# ...
